# %%
from tkinter import *
from tkinter import messagebox as msgbox
from openpyxl.workbook import Workbook
from openpyxl import load_workbook


def billings():
    
    
    bill=Tk()
    bill.title("Bill")
    bill.geometry("900x750")
    bill.config(bg="light grey")
    label=Label(bill,text="BILLINGS",font=("bold",20),bg="#709fb0",width=10).place(x=360,y=0)
    label_0=Label(bill,text="ENTER BILL",font=("bold",15),bg="#654062",fg="white",width=10).place(x=2,y=40)
    label_1=Label(bill,text="COSTUMER NAME",font=("bold",10),bg="#f2edd7",width=15).place(x=0,y=85)
    label_2=Label(bill,text="CITY",font=("bold",10),bg="#f2edd7",width=4).place(x=0,y=115)
    label_3=Label(bill,text="GSTIN",font=("bold",10),bg="#f2edd7",width=5).place(x=0,y=145)
    label_4=Label(bill,text="DATE",font=("bold",10),bg="#f2edd7",width=5).place(x=0,y=175)
    entry_1=Entry(bill,width=35)
    entry_1.place(x=170,y=85)#name
    entry_2=Entry(bill,width=25)
    entry_2.place(x=170,y=115)#city
    entry_3=Entry(bill,width=20)
    entry_3.place(x=170,y=145)#gstin
    entry_4=Entry(bill,width=13)
    entry_4.place(x=170,y=175)#date
    label_5=Label(bill,text="PRODUCT ID",font=("bold",12),bg="#a1cae2",width=11).place(x=0,y=210)
    label_6=Label(bill,text="PRODUCT NAME",font=("bold",12),bg="#a1cae2",width=16).place(x=150,y=210)
    label_7=Label(bill,text="QUANTITY",font=("bold",12),bg="#a1cae2",width=8).place(x=350,y=210)
    label_8=Label(bill,text="PRICE",font=("bold",12),bg="#a1cae2",width=5).place(x=470,y=210)
    label_9=Label(bill,text="TOTAL",font=("bold",12),bg="#a1cae2",width=5).place(x=570,y=210)
    
    entry_5=Entry(bill,width=15).place(x=2,y=250)
    entry_5_1=Entry(bill,width=15).place(x=2,y=270)
    entry_5_2=Entry(bill,width=15).place(x=2,y=290)
    entry_5_3=Entry(bill,width=15).place(x=2,y=310)
    entry_5_4=Entry(bill,width=15).place(x=2,y=330)
    entry_5_5=Entry(bill,width=15).place(x=2,y=350)
    entry_5_6=Entry(bill,width=15).place(x=2,y=370)
    entry_5_7=Entry(bill,width=15).place(x=2,y=390)
    entry_5_8=Entry(bill,width=15).place(x=2,y=410)
    entry_5_9=Entry(bill,width=15).place(x=2,y=430)
    
    entry_6=Entry(bill,width=22).place(x=160,y=250)
    entry_6_1=Entry(bill,width=22).place(x=160,y=270)
    entry_6_2=Entry(bill,width=22).place(x=160,y=290)
    entry_6_3=Entry(bill,width=22).place(x=160,y=310)
    entry_6_4=Entry(bill,width=22).place(x=160,y=330)
    entry_6_5=Entry(bill,width=22).place(x=160,y=350)
    entry_6_6=Entry(bill,width=22).place(x=160,y=370)
    entry_6_7=Entry(bill,width=22).place(x=160,y=390)
    entry_6_8=Entry(bill,width=22).place(x=160,y=410)
    entry_6_9=Entry(bill,width=22).place(x=160,y=430)
    
    r1=StringVar()
    r2=StringVar()
    r3=StringVar()
    r4=StringVar()
    r5=StringVar()
    r6=StringVar()
    r0=StringVar()
    r7=StringVar()
    r8=StringVar()
    r9=StringVar()
    totv=StringVar()
    
    def update():
        file=Workbook()
        file=load_workbook("invoice.xlsx",'w')
        sheet=file.active
        sheet.cell(column=1,row=sheet.max_row+1,value=entry_4.get())
        sheet.cell(column=2,row=sheet.max_row,value=entry_1.get())
        sheet.cell(column=3,row=sheet.max_row,value=entry_3.get())
        sheet.cell(column=4,row=sheet.max_row,value=tot.get())
        file.save("invoice.xlsx")
        mgg=msgbox.showinfo("update","saved successfully")
    
    def multiply():
        a0=p.get()
        b0=q.get()
        a1=p1.get()
        b1=q1.get()
        a2=p2.get()
        b2=q2.get()
        a3=p3.get()
        b3=q3.get()
        a4=p4.get()
        b4=q4.get()
        a5=p5.get()
        b5=q5.get()
        a6=p6.get()
        b6=q6.get()
        a7=p7.get()
        b7=q7.get()
        a8=p8.get()
        b8=q8.get()
        a9=p9.get()
        b9=q9.get()
        t=int(a0)*int(b0)
        t1=int(a1)*int(b1)
        t2=int(a2)*int(b2)
        t3=int(a3)*int(b3)
        t4=int(a4)*int(b4)
        t5=int(a5)*int(b5)
        t6=int(a6)*int(b6)
        t7=int(a7)*int(b7)
        t8=int(a8)*int(b8)
        t9=int(a9)*int(b9)

        tot=t+t1+t2+t3+t4+t5+t6+t7+t8+t9
        
        r0.set(t)
        r1.set(t1)
        r2.set(t2)
        r3.set(t3)
        r4.set(t4)
        r5.set(t5)
        r6.set(t6)
        r7.set(t7)
        r8.set(t8)
        r9.set(t9)
        totv.set(tot)
        
        
    
    p=Entry(bill,width=7)
    p.place(x=370,y=250)
    p1=Entry(bill,width=7)
    p1.place(x=370,y=270)
    p2=Entry(bill,width=7)
    p2.place(x=370,y=290)
    p3=Entry(bill,width=7)
    p3.place(x=370,y=310)
    p4=Entry(bill,width=7)
    p4.place(x=370,y=330)
    p5=Entry(bill,width=7)
    p5.place(x=370,y=350)
    p6=Entry(bill,width=7)
    p6.place(x=370,y=370)
    p7=Entry(bill,width=7)
    p7.place(x=370,y=390)
    p8=Entry(bill,width=7)
    p8.place(x=370,y=410)
    p9=Entry(bill,width=7)
    p9.place(x=370,y=430)
    
    q=Entry(bill,width=7)
    q.place(x=470,y=250)
    q1=Entry(bill,width=7)
    q1.place(x=470,y=270)
    q2=Entry(bill,width=7)
    q2.place(x=470,y=290)
    q3=Entry(bill,width=7)
    q3.place(x=470,y=310)
    q4=Entry(bill,width=7)
    q4.place(x=470,y=330)
    q5=Entry(bill,width=7)
    q5.place(x=470,y=350)
    q6=Entry(bill,width=7)
    q6.place(x=470,y=370)
    q7=Entry(bill,width=7)
    q7.place(x=470,y=390)
    q8=Entry(bill,width=7)
    q8.place(x=470,y=410)
    q9=Entry(bill,width=7)
    q9.place(x=470,y=430)
    
    m=Label(bill,textvariable=r0,width=9)
    m.place(x=570,y=250)
    m1=Label(bill,width=9,textvariable=r1)
    m1.place(x=570,y=270)
    m2=Label(bill,width=9,textvariable=r2)
    m2.place(x=570,y=290)
    m3=Label(bill,width=9,textvariable=r3)
    m3.place(x=570,y=310)
    m4=Label(bill,width=9,textvariable=r4)
    m4.place(x=570,y=330)
    m5=Label(bill,width=9,textvariable=r5)
    m5.place(x=570,y=350)
    m6=Label(bill,width=9,textvariable=r6)
    m6.place(x=570,y=370)
    m7=Label(bill,width=9,textvariable=r7)
    m7.place(x=570,y=390)
    m8=Label(bill,width=9,textvariable=r8)
    m8.place(x=570,y=410)
    m9=Label(bill,width=9,textvariable=r9)
    m9.place(x=570,y=430)
    

    
    label_10=Label(bill,text="TOTAL AMOUNT",font=("bold",12),bg="#f37121",width=15).place(x=390,y=465)
    total=Label(bill,width=12,textvariable=totv)
    total.place(x=565,y=465)
    Button(bill,text="SAVE",font=("bold",13),bg="gold",width=5,command=update).place(x=12,y=560)
    Button(bill,text="NEW BILL",font=("bold",13),bg="#f64b3c",width=9).place(x=140,y=560)
    Button(bill,text="PRINT",font=("bold",13),bg="purple1",width=6).place(x=290,y=560)
    Button(bill,text="CALCULATE",font=("bold",13),bg="#ee8572",width=10,command=multiply).place(x=410,y=560)
    Button(bill,text="CANCEL",font=("bold",13),bg="#7fcd91",width=7).place(x=580,y=560)
    
        
    def quit():
        bill.destroy()
    Button(bill,text="HOME",font=("bold",10),bg="cyan2",width=5,command=quit).place(x=810,y=30)
    bill.mainloop()
    
    
billings()
