# %%
from tkinter import *
from openpyxl.workbook import Workbook
from openpyxl import load_workbook
from tkinter import messagebox 


def report1():
    msg=messagebox.showinfo("ERROR","No records found for year 2018 - 2019")
    
def report2():
    r2=Tk()
    r2.geometry("650x650")
    r2.title("report")
    head=Label(r2,text="REPORT FOR YEAR 2019 - 2020",width=30,bg="red").place(x=210,y=15)
    wb=Workbook()
    def get_report():
        wb=load_workbook("report_19_20.xlsx")
        ws=wb.active
        column_a=ws['A']
        column_b=ws['B']
        column_c=ws['C']
        column_d=ws['D']
        list_a=''
        list_b=''
        list_c=''
        list_d=''

        for cell in column_a:
            list_a=f'{list_a+str(cell.value)}\n'
        quar.config(text=list_a)
        for cell in column_b:
            list_b=f'{list_b+str(cell.value)}\n'
        tar.config(text=list_b)
        for cell in column_c:
            list_c=f'{list_c+str(cell.value)}\n'
        mar.config(text=list_c)
        for cell in column_d:
             list_d=f'{list_d+str(cell.value)}\n'
        pro.config(text=list_d) 
    
    quar=Label(r2,width=25,height=10)
    quar.place(x=2,y=70)
    tar=Label(r2,width=30,height=10)
    tar.place(x=110,y=70)
    mar=Label(r2,width=30,height=10)
    mar.place(x=260,y=70)
    pro=Label(r2,width=30,height=10)
    pro.place(x=420,y=70)
    vr=Button(r2,text="View report",bg="light pink",command=get_report).place(x=20,y=60)

    r2.mainloop()
    
def report3():
    r3=Tk()
    r3.geometry("650x650")
    r3.title("report")
    head=Label(r3,text="REPORT FOR YEAR 2020 - 2021",width=30,bg="red").place(x=210,y=15)
    wb=Workbook()
    def get_report():
        wb=load_workbook("report_20_21.xlsx")
        ws=wb.active
        column_a=ws['A']
        column_b=ws['B']
        column_c=ws['C']
        column_d=ws['D']
        list_a=''
        list_b=''
        list_c=''
        list_d=''

        for cell in column_a:
            list_a=f'{list_a+str(cell.value)}\n'
        quar.config(text=list_a)
        for cell in column_b:
            list_b=f'{list_b+str(cell.value)}\n'
        tar.config(text=list_b)
        for cell in column_c:
            list_c=f'{list_c+str(cell.value)}\n'
        mar.config(text=list_c)
        for cell in column_d:
             list_d=f'{list_d+str(cell.value)}\n'
        pro.config(text=list_d) 
    
    quar=Label(r3,width=25,height=10)
    quar.place(x=2,y=70)
    tar=Label(r3,width=30,height=10)
    tar.place(x=110,y=70)
    mar=Label(r3,width=30,height=10)
    mar.place(x=260,y=70)
    pro=Label(r3,width=30,height=10)
    pro.place(x=420,y=70)
    vr=Button(r3,text="View report",bg="light pink",command=get_report).place(x=20,y=60)

    r3.mainloop()
    
def reports():
    rep=Tk()
    rep.geometry("600x730")
    rep.config(bg="yellow green")
    rep.title("REPORTS")
    dash=Button(rep,text="Dashbaord",bg="red").place(x=475,y=35)
    ti=Label(rep,text="SALES REPORTS",font=("bold",20),bg="magenta").place(x=180,y=0)
    year1=Button(rep,text="REPORT FOR 2018-2019",font=("bold",10),command=report1).place(x=20,y=60)
    year2=Button(rep,text="REPORT FOR 2019-2020",font=("bold",10),command=report2).place(x=20,y=120)
    year3=Button(rep,text="REPORT FOR 2020-2021",font=("bold",10),command=report3).place(x=20,y=180)
    update=Button(rep,text="Update",height=2,width=10,bg="slate blue").place(x=50,y=500)
    prin=Button(rep,text="Print",height=2,width=10,bg="slate blue").place(x=250,y=500)
    generate=Button(rep,text="Generate",height=2,width=10,bg="slate blue").place(x=450,y=500)
    rep.mainloop()
reports()
